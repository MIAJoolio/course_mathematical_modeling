# %%
import pandas as pd

# %%
pd.read_excel('data/23230000100010200001_Естественный_прирост_населения_за_год.xlsx')
# Out:
#    Unnamed: 0  Unnamed: 1  \
# 0         NaN         NaN
# 1     2010 г.         NaN
# 2     2011 г.         NaN
# 3     2012 г.         NaN
# 4     2013 г.         NaN
# 5     2014 г.         NaN
# 6     2015 г.         NaN
# 7     2016 г.         NaN
# 8     2017 г.         NaN
# 9     2018 г.         NaN
# 10    2019 г.         NaN
# 11    2020 г.         NaN
# 12    2021 г.         NaN
# 13    2022 г.         NaN
# 14    2023 г.         NaN
#
#    23230000100010200001 Естественный прирост населения за год  \
# 0                    w2:p_mest:12 городское население
# 1                                             -157841
# 2                                              -86649
# 3                                             2038.99
# 4                                               24805
# 5                                               32050
# 6                                            93391.99
# 7                                            71646.99
# ...
